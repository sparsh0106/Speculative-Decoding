# %% [markdown]
# # **Notebook 02 — Vanilla Autoregressive Decoding**

# %% [markdown]
# #### *Goal for this notebook*:
# - Implement greedy decoding outselves
# - Understand why generation is sequential
# - Measure target-model forward passes
# - Implement decoding **without KV Cache first**
# - Implement decoding **with KV Cache**
# - Verify both produce the same greedy output
# - establish our baseline for speculative decoding
